# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
students = pd.read_csv("ucdavis.csv")
g = sns.FacetGrid(students, hue="gender", palette="Set1", size=8)
g.map(plt.scatter, "gpa", "computer", s=250, linewidth=0.65,
edgecolor="white")
g.add_legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Another way to split strings
Maindata = 'From ossama.embarak@hct.ac.ae Sunday Jan 4 09:30:50 2017'
name= Maindata[ :atpost].replace('From','').upper()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\CUTM\Desktop\Python Tutorial\Data Visualisation\.ipynb_checkpoints\lession 1-checkpoint.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/CUTM/Desktop/Python%20Tutorial/Data%20Visualisation/.ipynb_checkpoints/lession%201-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Another way to split strings
#       <a href='vscode-notebook-cell:/c%3A/Users/CUTM/Desktop/Python%20Tutorial/Data%20Visualisation/.ipynb_checkpoints/lession%201-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> Maindata = 'From ossama.embarak@hct.ac.ae Sunday Jan 4 09:30:50 2017'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/CUTM/Desktop/Python%20Tutorial/Data%20Visualisation/.ipynb_checkpoints/lession%201-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> name= Maindata[ :atpost].replace('From','').upper()
#
# ...
